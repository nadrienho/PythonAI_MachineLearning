# %%
import pandas as pd

# %%
tips = pd.read_excel('/content/Tip_data.xlsx')
tips
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
#tips.drop(['Unnamed: 0'], axis=1)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
import seaborn as sns
sns.displot(tips['total_bill'])

# %%
sns.displot(tips['total_bill'],bins = 30)

# %%
sns.displot(tips['total_bill'],bins = 100)

# %%
sns.displot(tips['total_bill'],kde=True, bins = 30)

# %%
sns.jointplot(tips['total_bill'])

# %%
sns.jointplot(x='total_bill',y ='tip', data = tips)

# %%
sns.jointplot(x='total_bill',y ='tip', data = tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y ='tip', data = tips,kind='reg')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.pairplot(tips, hue='sex', palette='coolwarm')

# %%
sns.barplot(x='sex',y='total_bill',data = tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.histplot(data=tips, x="total_bill",y="tip", hue="sex", multiple="stack")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=tips, x="total_bill", hue="smoker", multiple="stack")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
d = {'a':10,'b':20,'c':30}
arr=np.array([10,20,30])

# %%
pd.Series(data=my_list) #creating panda series
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list, index=labels) #matching labels to my_list
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data=arr)#feeding an array
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)#feeding a dictionary to the series func
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
from numpy.random import randn#to generate random numbers

# %%
a = randn(5,4)
a
# Out:
# array([[-0.37429975,  0.17441208, -0.55723697, -0.45142575],
#        [ 2.4311354 , -0.23106042, -0.48867453,  0.16193026],
#        [ 0.9216526 ,  0.04196878, -0.71843159,  1.51733847],
#        [-0.67372317, -0.71493644, -0.17277208,  2.10268536],
#        [-0.12648217,  0.71000598,  0.9918555 ,  0.06341633]])

# %%
'A B C D E'.split()
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
df = pd.DataFrame(a,index='A B C D E'.split(),columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A -0.374300  0.174412 -0.557237 -0.451426
# B  2.431135 -0.231060 -0.488675  0.161930
# C  0.921653  0.041969 -0.718432  1.517338
# D -0.673723 -0.714936 -0.172772  2.102685
# E -0.126482  0.710006  0.991855  0.063416

# %%
df['W']
# Out:
# A   -0.374300
# B    2.431135
# C    0.921653
# D   -0.673723
# E   -0.126482
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df[['W','X']]
# Out:
#           W         X
# A -0.374300  0.174412
# B  2.431135 -0.231060
# C  0.921653  0.041969
# D -0.673723 -0.714936
# E -0.126482  0.710006

# %%
type(df[['W','X']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (5, 4)

# %%
df['W'].shape
# Out:
# (5,)

# %%
df[['W']].shape
# Out:
# (5, 1)

# %%
df['new']=df['W']+df['X']
df
# Out:
#           W         X         Y         Z       new
# A -0.374300  0.174412 -0.557237 -0.451426 -0.199888
# B  2.431135 -0.231060 -0.488675  0.161930  2.200075
# C  0.921653  0.041969 -0.718432  1.517338  0.963621
# D -0.673723 -0.714936 -0.172772  2.102685 -1.388660
# E -0.126482  0.710006  0.991855  0.063416  0.583524

# %%
df_2=df.drop('new',axis=1)
df_2
# Out:
#           W         X         Y         Z
# A -0.374300  0.174412 -0.557237 -0.451426
# B  2.431135 -0.231060 -0.488675  0.161930
# C  0.921653  0.041969 -0.718432  1.517338
# D -0.673723 -0.714936 -0.172772  2.102685
# E -0.126482  0.710006  0.991855  0.063416

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.374300  0.174412 -0.557237 -0.451426 -0.199888
# B  2.431135 -0.231060 -0.488675  0.161930  2.200075
# C  0.921653  0.041969 -0.718432  1.517338  0.963621
# D -0.673723 -0.714936 -0.172772  2.102685 -1.388660
# E -0.126482  0.710006  0.991855  0.063416  0.583524

# %%
df.drop('new',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-d3484050cca8> in <cell line: 1>()
# ----> 1 df.drop('new',axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df
# Out:
#           W         X         Y         Z
# A -0.374300  0.174412 -0.557237 -0.451426
# B  2.431135 -0.231060 -0.488675  0.161930
# C  0.921653  0.041969 -0.718432  1.517338
# D -0.673723 -0.714936 -0.172772  2.102685
# E -0.126482  0.710006  0.991855  0.063416

# %%
df.iloc[2]
# Out:
# W    0.921653
# X    0.041969
# Y   -0.718432
# Z    1.517338
# Name: C, dtype: float64

# %%
df.loc['A']
# Out:
# W   -0.374300
# X    0.174412
# Y   -0.557237
# Z   -0.451426
# Name: A, dtype: float64

# %%
df.loc['C','X']
# Out:
# 0.04196877507558584

# %%
df.loc[['B','C'],['Y','Z']]
# Out:
#           Y         Z
# B -0.488675  0.161930
# C -0.718432  1.517338

# %%
df.iloc[:,:]
# Out:
#           W         X         Y         Z
# A -0.374300  0.174412 -0.557237 -0.451426
# B  2.431135 -0.231060 -0.488675  0.161930
# C  0.921653  0.041969 -0.718432  1.517338
# D -0.673723 -0.714936 -0.172772  2.102685
# E -0.126482  0.710006  0.991855  0.063416

# %%
df.iloc[:3,:]
# Out:
#           W         X         Y         Z
# A -0.374300  0.174412 -0.557237 -0.451426
# B  2.431135 -0.231060 -0.488675  0.161930
# C  0.921653  0.041969 -0.718432  1.517338

# %%
df.iloc[:,2:]
# Out:
#           Y         Z
# A -0.557237 -0.451426
# B -0.488675  0.161930
# C -0.718432  1.517338
# D -0.172772  2.102685
# E  0.991855  0.063416

# %%
df.iloc[:3,:2]
# Out:
#           W         X
# A -0.374300  0.174412
# B  2.431135 -0.231060
# C  0.921653  0.041969

# %%
df>0
# Out:
#        W      X      Y      Z
# A  False   True  False  False
# B   True  False  False   True
# C   True   True  False   True
# D  False  False  False   True
# E  False   True   True   True

# %%
df>0
# Out:
#        W      X      Y      Z
# A  False   True  False  False
# B   True  False  False   True
# C   True   True  False   True
# D  False  False  False   True
# E  False   True   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN  0.174412       NaN       NaN
# B  2.431135       NaN       NaN  0.161930
# C  0.921653  0.041969       NaN  1.517338
# D       NaN       NaN       NaN  2.102685
# E       NaN  0.710006  0.991855  0.063416

# %%
df
# Out:
#           W         X         Y         Z
# A -0.374300  0.174412 -0.557237 -0.451426
# B  2.431135 -0.231060 -0.488675  0.161930
# C  0.921653  0.041969 -0.718432  1.517338
# D -0.673723 -0.714936 -0.172772  2.102685
# E -0.126482  0.710006  0.991855  0.063416

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# B  2.431135 -0.231060 -0.488675  0.161930
# C  0.921653  0.041969 -0.718432  1.517338

# %%
df[df['W']>0]['Z']
# Out:
# B    0.161930
# C    1.517338
# Name: Z, dtype: float64

# %%
df[df['W']>0][['Z','Y']]
# Out:
#           Z         Y
# B  0.161930 -0.488675
# C  1.517338 -0.718432

# %%
df[(df['W']<0)&(df['X']<0)]
# Out:
#           W         X         Y         Z
# D -0.673723 -0.714936 -0.172772  2.102685

# %%
df
# Out:
#           W         X         Y         Z
# A -0.374300  0.174412 -0.557237 -0.451426
# B  2.431135 -0.231060 -0.488675  0.161930
# C  0.921653  0.041969 -0.718432  1.517338
# D -0.673723 -0.714936 -0.172772  2.102685
# E -0.126482  0.710006  0.991855  0.063416

# %%
df[(df['W']<0)|(df['X']<0)]['Y']
# Out:
# A   -0.557237
# B   -0.488675
# D   -0.172772
# E    0.991855
# Name: Y, dtype: float64

# %%
df_3=df[df>0]
df_3
# Out:
#           W         X         Y         Z
# A       NaN  0.174412       NaN       NaN
# B  2.431135       NaN       NaN  0.161930
# C  0.921653  0.041969       NaN  1.517338
# D       NaN       NaN       NaN  2.102685
# E       NaN  0.710006  0.991855  0.063416

# %%
df_3.dropna()
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z]
# Index: []

# %%
df_3.loc['Z','A']=1

# %%
df_3.drop('A',axis=1,inplace=True)

# %%
df_3
# Out:
#           W         X         Y         Z
# B  2.431135       NaN       NaN  0.161930
# C  0.921653  0.041969       NaN  1.517338
# D       NaN       NaN       NaN  2.102685
# E       NaN  0.710006  0.991855  0.063416
# Z       NaN       NaN       NaN       NaN

# %%
df_3.loc['Z','Z']=1
df_3
# Out:
#           W         X         Y         Z
# B  2.431135       NaN       NaN  0.161930
# C  0.921653  0.041969       NaN  1.517338
# D       NaN       NaN       NaN  2.102685
# E       NaN  0.710006  0.991855  0.063416
# Z       NaN       NaN       NaN  1.000000

# %%
df_3.dropna(axis=1)
# Out:
#           Z
# B  0.161930
# C  1.517338
# D  2.102685
# E  0.063416
# Z  1.000000

# %%
df_3.fillna(value='sth')
# Out:
#           W         X         Y         Z
# B  2.431135       sth       sth  0.161930
# C  0.921653  0.041969       sth  1.517338
# D       sth       sth       sth  2.102685
# E       sth  0.710006  0.991855  0.063416
# Z       sth       sth       sth  1.000000

# %%
df_3.fillna(value=df_3['W'].mean()).  #filling the non values with the mean of column W
# Out:
#           W         X         Y         Z
# B  2.431135  1.676394  1.676394  0.161930
# C  0.921653  0.041969  1.676394  1.517338
# D  1.676394  1.676394  1.676394  2.102685
# E  1.676394  0.710006  0.991855  0.063416
# Z  1.676394  1.676394  1.676394  1.000000
